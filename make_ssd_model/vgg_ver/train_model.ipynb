# %% [markdown]
# # モデルを学習するnotebook

# %%
import pandas as pd
from math import sqrt as sqrt
from itertools import product as product

import torch
import torch.nn as nn
import torch.nn.init as init
import torch.nn.functional as F
from torch.autograd import Function
from torchsummary import summary
import torch.utils.data as data
import torch.optim as optim

import ast
import cv2
import numpy as np
import time
import random
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold

# %%
from utils.ssd_model import SSD
from utils.ssd_model import MultiBoxLoss

# %%
class EarlyStopping:
    """Early stops the training if validation loss doesn't improve after a given patience."""
    def __init__(self, path, patience=7, verbose=False, delta=0, trace_func=print):
        """
        Args:
            patience (int): How long to wait after last time validation loss improved.
                            Default: 7
            verbose (bool): If True, prints a message for each validation loss improvement. 
                            Default: False
            delta (float): Minimum change in the monitored quantity to qualify as an improvement.
                            Default: 0
            path (str): Path for the checkpoint to be saved to.
                            Default: 'checkpoint.pt'
            trace_func (function): trace print function.
                            Default: print            
        """
        self.patience = patience
        self.verbose = verbose
        self.counter = 0
        self.best_score = None
        self.early_stop = False
        self.val_loss_min = np.Inf
        self.delta = delta
        self.path = path
        self.trace_func = trace_func
    def __call__(self, val_loss, model):

        score = -val_loss

        if self.best_score is None:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
        elif score < self.best_score + self.delta:
            self.counter += 1
            self.trace_func(f'EarlyStopping counter: {self.counter} out of {self.patience}')
            if self.counter >= self.patience:
                self.early_stop = True
        else:
            self.best_score = score
            self.save_checkpoint(val_loss, model)
            self.counter = 0

    def save_checkpoint(self, val_loss, model):
        '''Saves model when validation loss decrease.'''
        if self.verbose:
            self.trace_func(f'Validation loss decreased ({self.val_loss_min:.6f} --> {val_loss:.6f}).  Saving model ...')
        torch.save(model.state_dict(), self.path)
        self.val_loss_min = val_loss

# %%
input_size = 300
color_mean = (0, 0)
voc_classes = ['ring']

# %%
ssd_cfg = {
    'num_classes': 2,  # 背景クラスを含めた合計クラス数
    'input_size': input_size,  # 画像の入力サイズ
    'bbox_aspect_num': [4, 6, 6, 6, 4, 4],  # 出力するDBoxのアスペクト比の種類
    'feature_maps': [38, 19, 10, 5, 3, 1],  # 各sourceの画像サイズ   
#     'feature_maps': [38, 19, 10, 5, 3, 1],  # 各sourceの画像サイズ
    'steps': [8, 16, 32, 64, 100, 300],  # DBOXの大きさを決める
    'min_sizes': [30, 60, 111, 162, 213, 264],  # DBOXの大きさを決める
    'max_sizes': [60, 111, 162, 213, 264, 315],  # DBOXの大きさを決める
    'aspect_ratios': [[2], [2, 3], [2, 3], [2, 3], [2], [2]],
}

# %%
# 学習データの読み込み
# 学習データはまだ上げていないです。
label = pd.read_csv('../data_for_ssd/MWP_data/ring_selection_for_ssd/std_many/augmentation_for_ssd_label.csv')
data = np.load('../data_for_ssd/MWP_data/ring_selection_for_ssd/std_many/augmentation_for_ssd.npy')
data = data[:,:,:,:2]
data = np.swapaxes(data, 2, 3)
data = np.swapaxes(data, 1, 2)

# %%
print(len(label))
print(data.shape)
# Out:
# 10910
# (10910, 2, 300, 300)

# %%
label = label.drop('Unnamed: 0', axis=1)
# label = label.drop('index', axis=1)
label
# Out:
#                          fits  \
# 0      spitzer_00300+0000_rgb
# 1      spitzer_00300+0000_rgb
# 2      spitzer_00300+0000_rgb
# 3      spitzer_00300+0000_rgb
# 4      spitzer_00300+0000_rgb
# ...                       ...
# 10905  spitzer_35700+0000_rgb
# 10906  spitzer_35700+0000_rgb
# 10907  spitzer_35700+0000_rgb
# 10908  spitzer_35700+0000_rgb
# 10909  spitzer_35700+0000_rgb
#
#                                                     name  \
# 0                                  ['2G0020120-0068213']
# 1                                  ['2G0020120-0068213']
# 2                                  ['2G0020120-0068213']
# 3                                  ['2G0020120-0068213']
# 4                                  ['2G0020120-0068213']
# ...                                                  ...
# 10905         ['2G3563404-0009054', '2G3562769-0007904']
# 10906  ['2G3579667-0016881', '2G3579868-0015789', '2G...
# 10907         ['2G3558423-0048948', '2G3558804-0052267']
# 10908         ['2G3558423-0048948', '2G3558804-0052267']
# 10909         ['2G3571471-0010057', '2G3572427-0011073']
#
#                                                     xmin  \
# 0                                   [0.1365964173721316]
# 1                                   [0.2680902043345587]
# 2                                  [0.20913421224965428]
# 3                                [0.0013299567596892655]
# 4                                   [0.0362237721148361]
# ...                                                  ...
# 10905           [0.2451006239665258, 0.5459186474259973]
# 10906  [0.6169360219919319, 0.4533268855395715, 0.303...
# 10907         [0.4062549266650938, 0.027078547797243238]
# 10908         [0.40473551847200395, 0.11204213937229014]
# 10909           [0.912925108459545, 0.27575974720993696]
#
#                                                     xmax  \
# 0                                  [0.23625005149378678]
# 1                                   [0.5759350668725902]
# 2                                   [0.7757558768455542]
# 3                                   [0.8233135459636813]
# 4                                  [0.11609338729111267]
# ...                                                  ...
# 10905           [0.3225072113401268, 0.7007318221731992]
# 10906  [0.6946688673583395, 0.5606722436887062, 0.491...
# 10907           [0.5988846380979796, 0.4630299925664748]
# 10908           [0.5534300160634377, 0.4485612597718746]
# 10909           [0.9693407921414064, 0.3388125686939263]
#
#                                                     ymin  \
# 0                                   [0.5551416764976318]
# 1                                  [0.11622007366783164]
# 2                                  [0.17891439044007815]
# 3                                  [0.13284732971717245]
# 4                                  [0.07988582797457988]
# ...                                                  ...
# 10905         [0.45632328754134577, 0.47901142698633115]
# 10906  [0.7791167239108852, 0.8450045666568464, 0.750...
# 10907           [0.7005793951317584, 0.3545218091713647]
# 10908          [0.3143074011994009, 0.04717904130453973]
# 10909           [0.529232208150133, 0.45887853346135005]
#
#                                                     ymax     id
# 0                                   [0.6547953106192858]      0
# 1                                  [0.42406493620585944]      1
# 2                                   [0.7455360550359712]      2
# 3                                   [0.9548309189211464]      3
# 4                                  [0.15975544315085544]      4
# ...                                                  ...    ...
# 10905           [0.5337298749149418, 0.6338246017335217]  10905
# 10906  [0.8568495692769483, 0.9523499248059714, 0.939...  10906
# 10907           [0.8932091065648169, 0.7904732539407884]  10907
# 10908            [0.463001898790974, 0.3836981617042862]  10908
# 10909           [0.5856478918321517, 0.5219313549456484]  10909
#
# [10910 rows x 7 columns]

# %%
# pandasのデータにlistが入っていると、listが文字列になってしまうため、これを実施
label['xmin'] = [ast.literal_eval(d) for d in label['xmin']]
label['xmax'] = [ast.literal_eval(d) for d in label['xmax']]
label['ymin'] = [ast.literal_eval(d) for d in label['ymin']]
label['ymax'] = [ast.literal_eval(d) for d in label['ymax']]

# %%
#  [[xmin1, ymin1, xmax1, ymax1, label1],  [xmin2, ymin2, xmax2, ymax2, label2], ・・・・・・・・・・・]と一つの画像に対するannotationを作る。
label_list = []
for i in range(len(label)):
    lab = []
    for k in range(len(label['xmin'][i])):
        labe = []
        labe.append(label['xmin'][i][k])
        labe.append(label['ymin'][i][k])
        labe.append(label['xmax'][i][k])
        labe.append(label['ymax'][i][k])
        labe.append(0)
        lab.append(labe)
    label_list.append(np.array(lab))

# for i in range(2000):
#     label_list.append(np.array([])[:,None])

# %%
# 一つの画像に二つのbubbleもあれば、一つのbubbleもある。
label_list[1].shape, label_list[-1].shape
# Out:
# ((1, 5), (2, 5))

# %%
kf = KFold(n_splits=2, shuffle=True)
train_data_list = []
train_label_list = []
test_data_list = []
test_label_list = []
for train_index, test_index in kf.split(data, label_list):
    train_data_list.append(data[train_index])
    train_label_list.append([label_list[k] for k in train_index])
    test_data_list.append(data[test_index])
    test_label_list.append([label_list[k] for k in test_index])

# %%
print(len(train_data_list[0]), len(train_label_list[0]), len(test_data_list[0]), len(test_label_list[0]))
# Out:
# 5455 5455 5455 5455

# %%
train_data_list[0].shape
# Out:
# (5455, 2, 300, 300)

# %%
def od_collate_fn(batch):
    targets = []
    imgs = []
    for sample in batch:
        imgs.append(sample[0])
        targets.append(torch.FloatTensor(sample[1]))
    imgs = torch.stack(imgs, dim=0)
        
    return imgs, targets

# %%
class DataSet():
    def __init__(self, data, label):
        self.label = label
        self.data = data
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, index):
        return self.data[index], self.label[index]

# %%
batch_size = 32

# %%
train_dataset = DataSet(torch.Tensor(train_data_list[0]), train_label_list[0])
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=od_collate_fn)

test_dataset = DataSet(torch.Tensor(test_data_list[0]), test_label_list[0])
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=True, collate_fn=od_collate_fn)

# %%
dataloaders_dict = {"train": train_loader, "val": test_loader}

# %%
#転移学習している。
# ネットにあるパラメーターを読み込む
net = SSD(phase='train', cfg=ssd_cfg)
CNN_weight = torch.load('ssd300_mAP_77.43_v2.pth')

# %%
net.vgg[0].weight = nn.Parameter(CNN_weight['vgg.0.weight'][:,:2,:,:])#.detach().numpy().copy()
net.vgg[0].bias = nn.Parameter(CNN_weight['vgg.0.bias'])
net.vgg[2].weight = nn.Parameter(CNN_weight['vgg.2.weight'])
net.vgg[2].bias = nn.Parameter(CNN_weight['vgg.2.bias'])
net.vgg[5].weight = nn.Parameter(CNN_weight['vgg.5.weight'])
net.vgg[5].bias = nn.Parameter(CNN_weight['vgg.5.bias'])
net.vgg[7].weight = nn.Parameter(CNN_weight['vgg.7.weight'])
net.vgg[7].bias = nn.Parameter(CNN_weight['vgg.7.bias'])
net.vgg[10].weight = nn.Parameter(CNN_weight['vgg.10.weight'])
net.vgg[10].bias = nn.Parameter(CNN_weight['vgg.10.bias'])
net.vgg[12].weight = nn.Parameter(CNN_weight['vgg.12.weight'])
net.vgg[12].bias = nn.Parameter(CNN_weight['vgg.12.bias'])
net.vgg[14].weight = nn.Parameter(CNN_weight['vgg.14.weight'])
net.vgg[14].bias = nn.Parameter(CNN_weight['vgg.14.bias'])
net.vgg[17].weight = nn.Parameter(CNN_weight['vgg.17.weight'])
net.vgg[17].bias = nn.Parameter(CNN_weight['vgg.17.bias'])
net.vgg[19].weight = nn.Parameter(CNN_weight['vgg.19.weight'])
net.vgg[19].bias = nn.Parameter(CNN_weight['vgg.19.bias'])
net.vgg[21].weight = nn.Parameter(CNN_weight['vgg.21.weight'])
net.vgg[21].bias = nn.Parameter(CNN_weight['vgg.21.bias'])
net.vgg[24].weight = nn.Parameter(CNN_weight['vgg.24.weight'])
net.vgg[24].bias = nn.Parameter(CNN_weight['vgg.24.bias'])
net.vgg[26].weight = nn.Parameter(CNN_weight['vgg.26.weight'])
net.vgg[26].bias = nn.Parameter(CNN_weight['vgg.26.bias'])
net.vgg[28].weight = nn.Parameter(CNN_weight['vgg.28.weight'])
net.vgg[28].bias = nn.Parameter(CNN_weight['vgg.28.bias'])
net.vgg[31].weight = nn.Parameter(CNN_weight['vgg.31.weight'])
net.vgg[31].bias = nn.Parameter(CNN_weight['vgg.31.bias'])
net.vgg[33].weight = nn.Parameter(CNN_weight['vgg.33.weight'])
net.vgg[33].bias = nn.Parameter(CNN_weight['vgg.33.bias'])

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
net.to(device)
# Out:
# SSD(
#   (vgg): ModuleList(
#     (0): Conv2d(2, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=True)
#     (17): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (18): ReLU(inplace=True)
#     (19): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (25): ReLU(inplace=True)
#     (26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (27): ReLU(inplace=True)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): MaxPool2d(kernel_size=3, stride=1, padding=1, dilation=1, ceil_mode=False)
#     (31): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(6, 6), dilation=(6, 6))
#     (32): ReLU(inplace=True)
#     (33): Conv2d(1024, 1024, kernel_size=(1, 1), stride=(1, 1))
#     (34): ReLU(inplace=True)
#   )
#   (extras): ModuleList(
#     (0): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (2): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1))
#     (3): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#     (4): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     (5): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#     (6): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1))
#     (7): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1))
#   )
#   (L2Norm): L2Norm()
#   (loc): ModuleList(
#     (0): Conv2d(512, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2d(1024, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): Conv2d(512, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): Conv2d(256, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): Conv2d(256, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): Conv2d(256, 16, kernel_size=(1, 1), stride=(1, 1))
#   )
#   (conf): ModuleList(
#     (0): Conv2d(512, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): Conv2d(1024, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (2): Conv2d(512, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): Conv2d(256, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): Conv2d(256, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (5): Conv2d(256, 8, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %%
summary(net, (2, 300, 300))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 300, 300]           1,216
#               ReLU-2         [-1, 64, 300, 300]               0
#             Conv2d-3         [-1, 64, 300, 300]          36,928
#               ReLU-4         [-1, 64, 300, 300]               0
#          MaxPool2d-5         [-1, 64, 150, 150]               0
#             Conv2d-6        [-1, 128, 150, 150]          73,856
#               ReLU-7        [-1, 128, 150, 150]               0
#             Conv2d-8        [-1, 128, 150, 150]         147,584
#               ReLU-9        [-1, 128, 150, 150]               0
#         MaxPool2d-10          [-1, 128, 75, 75]               0
#            Conv2d-11          [-1, 256, 75, 75]         295,168
#              ReLU-12          [-1, 256, 75, 75]               0
#            Conv2d-13          [-1, 256, 75, 75]         590,080
#              ReLU-14          [-1, 256, 75, 75]               0
#            Conv2d-15          [-1, 256, 75, 75]         590,080
#              ReLU-16          [-1, 256, 75, 75]               0
#         MaxPool2d-17          [-1, 256, 38, 38]               0
#            Conv2d-18          [-1, 512, 38, 38]       1,180,160
#              ReLU-19          [-1, 512, 38, 38]               0
#            Conv2d-20          [-1, 512, 38, 38]       2,359,808
#              ReLU-21          [-1, 512, 38, 38]               0
#            Conv2d-22          [-1, 512, 38, 38]       2,359,808
#              ReLU-23          [-1, 512, 38, 38]               0
#            L2Norm-24          [-1, 512, 38, 38]             512
#         MaxPool2d-25          [-1, 512, 19, 19]               0
#            Conv2d-26          [-1, 512, 19, 19]       2,359,808
#              ReLU-27          [-1, 512, 19, 19]               0
#            Conv2d-28          [-1, 512, 19, 19]       2,359,808
#              ReLU-29          [-1, 512, 19, 19]               0
#            Conv2d-30          [-1, 512, 19, 19]       2,359,808
#              ReLU-31          [-1, 512, 19, 19]               0
#         MaxPool2d-32          [-1, 512, 19, 19]               0
#            Conv2d-33         [-1, 1024, 19, 19]       4,719,616
#              ReLU-34         [-1, 1024, 19, 19]               0
#            Conv2d-35         [-1, 1024, 19, 19]       1,049,600
#              ReLU-36         [-1, 1024, 19, 19]               0
#            Conv2d-37          [-1, 256, 19, 19]         262,400
#            Conv2d-38          [-1, 512, 10, 10]       1,180,160
#            Conv2d-39          [-1, 128, 10, 10]          65,664
#            Conv2d-40            [-1, 256, 5, 5]         295,168
#            Conv2d-41            [-1, 128, 5, 5]          32,896
#            Conv2d-42            [-1, 256, 3, 3]         295,168
#            Conv2d-43            [-1, 128, 3, 3]          32,896
#            Conv2d-44            [-1, 256, 1, 1]         295,168
#            Conv2d-45           [-1, 16, 38, 38]          73,744
#            Conv2d-46            [-1, 8, 38, 38]          36,872
#            Conv2d-47           [-1, 24, 19, 19]         221,208
#            Conv2d-48           [-1, 12, 19, 19]         110,604
#            Conv2d-49           [-1, 24, 10, 10]         110,616
#            Conv2d-50           [-1, 12, 10, 10]          55,308
#            Conv2d-51             [-1, 24, 5, 5]          55,320
#            Conv2d-52             [-1, 12, 5, 5]          27,660
#            Conv2d-53             [-1, 16, 3, 3]          36,880
#            Conv2d-54              [-1, 8, 3, 3]          18,440
#            Conv2d-55             [-1, 16, 1, 1]           4,112
#            Conv2d-56              [-1, 8, 1, 1]           2,056
# ================================================================
# Total params: 23,696,180
# Trainable params: 23,696,180
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.69
# Forward/backward pass size (MB): 412.63
# Params size (MB): 90.39
# Estimated Total Size (MB): 503.71
# ----------------------------------------------------------------

# %%
def weights_init(m):
    if isinstance(m, nn.Conv2d):
        init.kaiming_normal_(m.weight.data)
        if m.bias is not None:
            nn.init.constant_(m.bias, 0.0)

# %%
# net.vgg.apply(weights_init)
net.extras.apply(weights_init)
net.loc.apply(weights_init)
net.conf.apply(weights_init)
# Out:
# ModuleList(
#   (0): Conv2d(512, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (1): Conv2d(1024, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (2): Conv2d(512, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (3): Conv2d(256, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (4): Conv2d(256, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (5): Conv2d(256, 8, kernel_size=(1, 1), stride=(1, 1))
# )

# %%
# for i in net.parameters():
#     print(i.requires_grad)

# %%
list_ = []
for i in net.parameters():
    i = i.to('cpu').detach().numpy().ravel()
    list_.append(i)
    pass

list_ = np.concatenate(list_)
plt.hist(list_, bins=np.linspace(-0.5, 0.5, 50))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
criterion = MultiBoxLoss(jaccard_thresh=0.5, neg_pos=3, device=device)
optimizer = optim.SGD(net.parameters(), lr=1e-3, momentum=0.9, weight_decay=5e-4)

# %%
# モデルを学習させる関数を作成


def train_model(net, dataloaders_dict, criterion, optimizer, num_epochs, file_name):
    
    pos_tempo_list = []
    neg_tempo_list = []
    # GPUが使えるかを確認
    device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
    print("使用デバイス：", device)

    # ネットワークをGPUへ
    net.to(device)

    # ネットワークがある程度固定であれば、高速化させる
    torch.backends.cudnn.benchmark = True
    early_stopping = EarlyStopping(patience=20, verbose=True, path='weights/%s/earlystopping.pth'%(file_name))
    # イテレーションカウンタをセット
    logs = []

    # epochのループ
    for epoch in range(num_epochs):
        iteration = 0
        val_iter = 0
        epoch_train_loss = 0.0  # epochの損失和
        epoch_val_loss = 0.0  # epochの損失和
        # 開始時刻を保存
        t_epoch_start = time.time()
        t_iter_start = time.time()

        print('-------------')
        print('Epoch {}/{}'.format(epoch+1, num_epochs))
        print('-------------')

        # epochごとの訓練と検証のループ
        for phase in ['train', 'val']:
            if phase == 'train':
                net.train()  # モデルを訓練モードに
                print('（train）')
            else:
                net.eval()

            # データローダーからminibatchずつ取り出すループ
            for images, targets in dataloaders_dict[phase]:

                # GPUが使えるならGPUにデータを送る
                images = images.to(device, dtype=torch.float)
                targets = [ann.to(device, dtype=torch.float) for ann in targets]  # リストの各要素のテンソルをGPUへ
                # optimizerを初期化
                optimizer.zero_grad()

                # 順伝搬（forward）計算
                with torch.set_grad_enabled(phase == 'train'):
                    # 順伝搬（forward）計算
                    outputs = net(images)
                    # 損失の計算
                    loss_l, loss_c, pos_mask, neg_mask = criterion(outputs, targets)
                    loss = loss_l + loss_c
                    pos_tempo_list.append(pos_mask.to('cpu'))
                    neg_tempo_list.append(neg_mask.to('cpu'))
#                     print(loss)
                    # 訓練時はバックプロパゲーション
                    if phase == 'train':
                
                        loss.backward()  # 勾配の計算
                        nn.utils.clip_grad_value_(net.parameters(), clip_value=2.0)# 勾配が大きくなりすぎると計算が不安定になるので、clipで最大でも勾配2.0に留める

                        optimizer.step()  # パラメータ更新
                        epoch_train_loss += loss.item()
                        print("\r"+str(iteration)+'/'+str(int(train_data_list[0].shape[0]/batch_size))+'       ', end="")
                        iteration += 1

                    # 検証時
                    else:
                        epoch_val_loss += loss.item()
                        val_iter += 1              
        avg_train_loss = epoch_train_loss / iteration
        avg_val_loss = epoch_val_loss / val_iter
        
        print('\nepoch {} || Epoch_TRAIN_Loss:{:.4f} ||Epoch_VAL_Loss:{:.4f} '.format(epoch+1,
                                                                                  avg_train_loss,
                                                                                  avg_val_loss))
        # epochのphaseごとのlossと正解率
        t_epoch_finish = time.time()
        print('timer:  {:.4f} sec.'.format(t_epoch_finish - t_epoch_start))
        t_epoch_start = time.time()

        # ログを保存
        log_epoch = {'epoch': epoch+1,
                     'train_loss': avg_train_loss, 'val_loss': avg_val_loss}
        logs.append(log_epoch)
        df = pd.DataFrame(logs)
        df.to_csv("weights/%s/log_output.csv"%(file_name))
        
        early_stopping(epoch_val_loss, net)
    
        if early_stopping.early_stop:
            print('Early_Stopping')
            break
            
        epoch_train_loss = 0.0  # epochの損失和
        epoch_val_loss = 0.0  # epochの損失和

        # ネットワークを保存する
        if ((epoch+1) % 10 == 0):
            torch.save(net.state_dict(), 'weights/%s/ssd300_'%(file_name) +
                       str(epoch+1) + '.pth')
    return torch.cat(pos_tempo_list), torch.cat(neg_tempo_list)

# %%
num_epoch = 300
pd_frame = pd.DataFrame(columns=['iteration', 'phase', 'loss'])
pos_tensor, neg_tensor = train_model(net,dataloaders_dict , criterion, optimizer, 
                      num_epochs=num_epoch, file_name='weights_ring_select_8_9')
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 1/300
# -------------
# （train）
# 170/170
# epoch 1 || Epoch_TRAIN_Loss:6.0020 ||Epoch_VAL_Loss:6.7604
# timer:  100.6710 sec.
# Validation loss decreased (inf --> 1156.024933).  Saving model ...
# -------------
# Epoch 2/300
# -------------
# （train）
# 170/170
# epoch 2 || Epoch_TRAIN_Loss:5.5972 ||Epoch_VAL_Loss:7.8265
# timer:  97.0522 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 3/300
# -------------
# （train）
# 170/170
# epoch 3 || Epoch_TRAIN_Loss:6.0363 ||Epoch_VAL_Loss:5.8270
# timer:  97.1102 sec.
# Validation loss decreased (1156.024933 --> 996.419407).  Saving model ...
# -------------
# Epoch 4/300
# -------------
# （train）
# 170/170
# epoch 4 || Epoch_TRAIN_Loss:5.6471 ||Epoch_VAL_Loss:6.0597
# timer:  97.4283 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 5/300
# -------------
# （train）
# 170/170
# epoch 5 || Epoch_TRAIN_Loss:4.9955 ||Epoch_VAL_Loss:5.7174
# timer:  97.3624 sec.
# Validation loss decreased (996.419407 --> 977.682511).  Saving model ...
# -------------
# Epoch 6/300
# -------------
# （train）
# 170/170
# epoch 6 || Epoch_TRAIN_Loss:4.5570 ||Epoch_VAL_Loss:5.3715
# timer:  97.3914 sec.
# Validation loss decreased (977.682511 --> 918.532046).  Saving model ...
# -------------
# Epoch 7/300
# -------------
# （train）
# 170/170
# epoch 7 || Epoch_TRAIN_Loss:3.8176 ||Epoch_VAL_Loss:3.6788
# timer:  97.4860 sec.
# Validation loss decreased (918.532046 --> 629.071406).  Saving model ...
# -------------
# Epoch 8/300
# -------------
# （train）
# 170/170
# epoch 8 || Epoch_TRAIN_Loss:3.5358 ||Epoch_VAL_Loss:3.8705
# timer:  97.7742 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 9/300
# -------------
# （train）
# 170/170
# epoch 9 || Epoch_TRAIN_Loss:3.0029 ||Epoch_VAL_Loss:2.9805
# timer:  97.9502 sec.
# Validation loss decreased (629.071406 --> 509.673737).  Saving model ...
# -------------
# Epoch 10/300
# -------------
# （train）
# 170/170
# epoch 10 || Epoch_TRAIN_Loss:2.9458 ||Epoch_VAL_Loss:2.8875
# timer:  97.9599 sec.
# Validation loss decreased (509.673737 --> 493.764799).  Saving model ...
# -------------
# Epoch 11/300
# -------------
# （train）
# 170/170
# epoch 11 || Epoch_TRAIN_Loss:2.7040 ||Epoch_VAL_Loss:2.7895
# timer:  97.7610 sec.
# Validation loss decreased (493.764799 --> 477.003044).  Saving model ...
# -------------
# Epoch 12/300
# -------------
# （train）
# 170/170
# epoch 12 || Epoch_TRAIN_Loss:2.6016 ||Epoch_VAL_Loss:2.6644
# timer:  97.8394 sec.
# Validation loss decreased (477.003044 --> 455.615469).  Saving model ...
# -------------
# Epoch 13/300
# -------------
# （train）
# 170/170
# epoch 13 || Epoch_TRAIN_Loss:2.5285 ||Epoch_VAL_Loss:2.5935
# timer:  97.9775 sec.
# Validation loss decreased (455.615469 --> 443.491308).  Saving model ...
# -------------
# Epoch 14/300
# -------------
# （train）
# 170/170
# epoch 14 || Epoch_TRAIN_Loss:2.4586 ||Epoch_VAL_Loss:2.6519
# timer:  97.7850 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 15/300
# -------------
# （train）
# 170/170
# epoch 15 || Epoch_TRAIN_Loss:2.3542 ||Epoch_VAL_Loss:2.5372
# timer:  97.8669 sec.
# Validation loss decreased (443.491308 --> 433.866400).  Saving model ...
# -------------
# Epoch 16/300
# -------------
# （train）
# 170/170
# epoch 16 || Epoch_TRAIN_Loss:2.2923 ||Epoch_VAL_Loss:2.5056
# timer:  97.6937 sec.
# Validation loss decreased (433.866400 --> 428.461199).  Saving model ...
# -------------
# Epoch 17/300
# -------------
# （train）
# 170/170
# epoch 17 || Epoch_TRAIN_Loss:2.2443 ||Epoch_VAL_Loss:2.4230
# timer:  97.6971 sec.
# Validation loss decreased (428.461199 --> 414.324761).  Saving model ...
# -------------
# Epoch 18/300
# -------------
# （train）
# 170/170
# epoch 18 || Epoch_TRAIN_Loss:2.1358 ||Epoch_VAL_Loss:2.3587
# timer:  97.7055 sec.
# Validation loss decreased (414.324761 --> 403.344572).  Saving model ...
# -------------
# Epoch 19/300
# -------------
# （train）
# 170/170
# epoch 19 || Epoch_TRAIN_Loss:2.0521 ||Epoch_VAL_Loss:2.2694
# timer:  97.7583 sec.
# Validation loss decreased (403.344572 --> 388.069324).  Saving model ...
# -------------
# Epoch 20/300
# -------------
# （train）
# 170/170
# epoch 20 || Epoch_TRAIN_Loss:2.0461 ||Epoch_VAL_Loss:2.2878
# timer:  97.8689 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 21/300
# -------------
# （train）
# 170/170
# epoch 21 || Epoch_TRAIN_Loss:1.9505 ||Epoch_VAL_Loss:2.2483
# timer:  97.8562 sec.
# Validation loss decreased (388.069324 --> 384.464021).  Saving model ...
# -------------
# Epoch 22/300
# -------------
# （train）
# 170/170
# epoch 22 || Epoch_TRAIN_Loss:1.8769 ||Epoch_VAL_Loss:2.3478
# timer:  97.8145 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 23/300
# -------------
# （train）
# 170/170
# epoch 23 || Epoch_TRAIN_Loss:1.7872 ||Epoch_VAL_Loss:2.1111
# timer:  97.8127 sec.
# Validation loss decreased (384.464021 --> 360.996962).  Saving model ...
# -------------
# Epoch 24/300
# -------------
# （train）
# 170/170
# epoch 24 || Epoch_TRAIN_Loss:1.7196 ||Epoch_VAL_Loss:2.0742
# timer:  97.7972 sec.
# Validation loss decreased (360.996962 --> 354.686100).  Saving model ...
# -------------
# Epoch 25/300
# -------------
# （train）
# 170/170
# epoch 25 || Epoch_TRAIN_Loss:1.6786 ||Epoch_VAL_Loss:2.0655
# timer:  97.6630 sec.
# Validation loss decreased (354.686100 --> 353.205589).  Saving model ...
# -------------
# Epoch 26/300
# -------------
# （train）
# 170/170
# epoch 26 || Epoch_TRAIN_Loss:1.6545 ||Epoch_VAL_Loss:2.0795
# timer:  97.8844 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 27/300
# -------------
# （train）
# 170/170
# epoch 27 || Epoch_TRAIN_Loss:1.5799 ||Epoch_VAL_Loss:2.0221
# timer:  97.6753 sec.
# Validation loss decreased (353.205589 --> 345.783365).  Saving model ...
# -------------
# Epoch 28/300
# -------------
# （train）
# 170/170
# epoch 28 || Epoch_TRAIN_Loss:1.5069 ||Epoch_VAL_Loss:2.1581
# timer:  97.7181 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 29/300
# -------------
# （train）
# 170/170
# epoch 29 || Epoch_TRAIN_Loss:1.4436 ||Epoch_VAL_Loss:2.0540
# timer:  97.8459 sec.
# EarlyStopping counter: 2 out of 20
# -------------
# Epoch 30/300
# -------------
# （train）
# 170/170
# epoch 30 || Epoch_TRAIN_Loss:1.3939 ||Epoch_VAL_Loss:1.9747
# timer:  97.8695 sec.
# Validation loss decreased (345.783365 --> 337.677517).  Saving model ...
# -------------
# Epoch 31/300
# -------------
# （train）
# 170/170
# epoch 31 || Epoch_TRAIN_Loss:1.3776 ||Epoch_VAL_Loss:1.9905
# timer:  97.8245 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 32/300
# -------------
# （train）
# 170/170
# epoch 32 || Epoch_TRAIN_Loss:1.2949 ||Epoch_VAL_Loss:1.9759
# timer:  97.7583 sec.
# EarlyStopping counter: 2 out of 20
# -------------
# Epoch 33/300
# -------------
# （train）
# 170/170
# epoch 33 || Epoch_TRAIN_Loss:1.2254 ||Epoch_VAL_Loss:2.0398
# timer:  97.8387 sec.
# EarlyStopping counter: 3 out of 20
# -------------
# Epoch 34/300
# -------------
# （train）
# 170/170
# epoch 34 || Epoch_TRAIN_Loss:1.1828 ||Epoch_VAL_Loss:1.8641
# timer:  97.8138 sec.
# Validation loss decreased (337.677517 --> 318.760183).  Saving model ...
# -------------
# Epoch 35/300
# -------------
# （train）
# 170/170
# epoch 35 || Epoch_TRAIN_Loss:1.1148 ||Epoch_VAL_Loss:1.9387
# timer:  98.0614 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 36/300
# -------------
# （train）
# 170/170
# epoch 36 || Epoch_TRAIN_Loss:1.1080 ||Epoch_VAL_Loss:2.0666
# timer:  97.9942 sec.
# EarlyStopping counter: 2 out of 20
# -------------
# Epoch 37/300
# -------------
# （train）
# 170/170
# epoch 37 || Epoch_TRAIN_Loss:1.0770 ||Epoch_VAL_Loss:1.8774
# timer:  97.8102 sec.
# EarlyStopping counter: 3 out of 20
# -------------
# Epoch 38/300
# -------------
# （train）
# 170/170
# epoch 38 || Epoch_TRAIN_Loss:1.0263 ||Epoch_VAL_Loss:1.9199
# timer:  97.8065 sec.
# EarlyStopping counter: 4 out of 20
# -------------
# Epoch 39/300
# -------------
# （train）
# 170/170
# epoch 39 || Epoch_TRAIN_Loss:0.9724 ||Epoch_VAL_Loss:1.9269
# timer:  97.8573 sec.
# EarlyStopping counter: 5 out of 20
# -------------
# Epoch 40/300
# -------------
# （train）
# 170/170
# epoch 40 || Epoch_TRAIN_Loss:0.9466 ||Epoch_VAL_Loss:1.9192
# timer:  97.8577 sec.
# EarlyStopping counter: 6 out of 20
# -------------
# Epoch 41/300
# -------------
# （train）
# 170/170
# epoch 41 || Epoch_TRAIN_Loss:0.9168 ||Epoch_VAL_Loss:2.1374
# timer:  97.8686 sec.
# EarlyStopping counter: 7 out of 20
# -------------
# Epoch 42/300
# -------------
# （train）
# 170/170
# epoch 42 || Epoch_TRAIN_Loss:0.9102 ||Epoch_VAL_Loss:1.9558
# timer:  97.9212 sec.
# EarlyStopping counter: 8 out of 20
# -------------
# Epoch 43/300
# -------------
# （train）
# 170/170
# epoch 43 || Epoch_TRAIN_Loss:0.8241 ||Epoch_VAL_Loss:1.8878
# timer:  97.8200 sec.
# EarlyStopping counter: 9 out of 20
# -------------
# Epoch 44/300
# -------------
# （train）
# 170/170
# epoch 44 || Epoch_TRAIN_Loss:0.7896 ||Epoch_VAL_Loss:1.8908
# timer:  97.9974 sec.
# EarlyStopping counter: 10 out of 20
# -------------
# Epoch 45/300
# -------------
# （train）
# 170/170
# epoch 45 || Epoch_TRAIN_Loss:0.7580 ||Epoch_VAL_Loss:1.8897
# timer:  97.7819 sec.
# EarlyStopping counter: 11 out of 20
# -------------
# Epoch 46/300
# -------------
# （train）
# 170/170
# epoch 46 || Epoch_TRAIN_Loss:0.7123 ||Epoch_VAL_Loss:1.9407
# timer:  98.0675 sec.
# EarlyStopping counter: 12 out of 20
# -------------
# Epoch 47/300
# -------------
# （train）
# 170/170
# epoch 47 || Epoch_TRAIN_Loss:0.7315 ||Epoch_VAL_Loss:1.9624
# timer:  98.0505 sec.
# EarlyStopping counter: 13 out of 20
# -------------
# Epoch 48/300
# -------------
# （train）
# 170/170
# epoch 48 || Epoch_TRAIN_Loss:0.6938 ||Epoch_VAL_Loss:1.9160
# timer:  97.9887 sec.
# EarlyStopping counter: 14 out of 20
# -------------
# Epoch 49/300
# -------------
# （train）
# 170/170
# epoch 49 || Epoch_TRAIN_Loss:0.6835 ||Epoch_VAL_Loss:1.9402
# timer:  97.8839 sec.
# EarlyStopping counter: 15 out of 20
# -------------
# Epoch 50/300
# -------------
# （train）
# 170/170
# epoch 50 || Epoch_TRAIN_Loss:0.6230 ||Epoch_VAL_Loss:1.9378
# timer:  97.8137 sec.
# EarlyStopping counter: 16 out of 20
# -------------
# Epoch 51/300
# -------------
# （train）
# 170/170
# epoch 51 || Epoch_TRAIN_Loss:0.6433 ||Epoch_VAL_Loss:1.9024
# timer:  97.8179 sec.
# EarlyStopping counter: 17 out of 20
# -------------
# Epoch 52/300
# -------------
# （train）
# 170/170
# epoch 52 || Epoch_TRAIN_Loss:0.5777 ||Epoch_VAL_Loss:1.9786
# timer:  97.9006 sec.
# EarlyStopping counter: 18 out of 20
# -------------
# Epoch 53/300
# -------------
# （train）
# 170/170
# epoch 53 || Epoch_TRAIN_Loss:0.5757 ||Epoch_VAL_Loss:1.9362
# timer:  97.8365 sec.
# EarlyStopping counter: 19 out of 20
# -------------
# Epoch 54/300
# -------------
# （train）
# 170/170
# epoch 54 || Epoch_TRAIN_Loss:0.5268 ||Epoch_VAL_Loss:1.9791
# timer:  97.7053 sec.
# EarlyStopping counter: 20 out of 20
# Early_Stopping

# %%
torch.sum(pos_tensor, axis=0)
# Out:
# tensor([     0,      0,      0,  ..., 187110, 261954, 262062])

# %%
np.save('pos_ft.npy', pos_tensor.detach().numpy())

# %%
np.save('neg_ft.npy', neg_tensor.detach().numpy())

# %%
num_epoch = 300
pd_frame = pd.DataFrame(columns=['iteration', 'phase', 'loss'])
pd_loss = train_model(net,dataloaders_dict , criterion, optimizer, 
                      num_epochs=num_epoch, file_name='weights_ring_select_7_19_many')
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 1/300
# -------------
# （train）
# 365/366
# epoch 1 || Epoch_TRAIN_Loss:4.7217 ||Epoch_VAL_Loss:3.4005
# timer:  211.2438 sec.
# Validation loss decreased (inf --> 1247.973526).  Saving model ...
# -------------
# Epoch 2/300
# -------------
# （train）
# 365/366
# epoch 2 || Epoch_TRAIN_Loss:2.7384 ||Epoch_VAL_Loss:2.4235
# timer:  209.0006 sec.
# Validation loss decreased (1247.973526 --> 889.441406).  Saving model ...
# -------------
# Epoch 3/300
# -------------
# （train）
# 365/366
# epoch 3 || Epoch_TRAIN_Loss:2.2247 ||Epoch_VAL_Loss:2.2456
# timer:  209.0956 sec.
# Validation loss decreased (889.441406 --> 824.137323).  Saving model ...
# -------------
# Epoch 4/300
# -------------
# （train）
# 365/366
# epoch 4 || Epoch_TRAIN_Loss:2.0290 ||Epoch_VAL_Loss:1.9543
# timer:  209.0663 sec.
# Validation loss decreased (824.137323 --> 717.237922).  Saving model ...
# -------------
# Epoch 5/300
# -------------
# （train）
# 365/366
# epoch 5 || Epoch_TRAIN_Loss:1.8748 ||Epoch_VAL_Loss:1.8189
# timer:  209.0002 sec.
# Validation loss decreased (717.237922 --> 667.547874).  Saving model ...
# -------------
# Epoch 6/300
# -------------
# （train）
# 365/366
# epoch 6 || Epoch_TRAIN_Loss:1.7557 ||Epoch_VAL_Loss:1.7446
# timer:  209.4442 sec.
# Validation loss decreased (667.547874 --> 640.252168).  Saving model ...
# -------------
# Epoch 7/300
# -------------
# （train）
# 365/366
# epoch 7 || Epoch_TRAIN_Loss:1.6276 ||Epoch_VAL_Loss:1.6098
# timer:  209.8907 sec.
# Validation loss decreased (640.252168 --> 590.781815).  Saving model ...
# -------------
# Epoch 8/300
# -------------
# （train）
# 365/366
# epoch 8 || Epoch_TRAIN_Loss:1.5286 ||Epoch_VAL_Loss:1.4752
# timer:  209.7527 sec.
# Validation loss decreased (590.781815 --> 541.402333).  Saving model ...
# -------------
# Epoch 9/300
# -------------
# （train）
# 365/366
# epoch 9 || Epoch_TRAIN_Loss:1.4534 ||Epoch_VAL_Loss:1.4282
# timer:  209.3037 sec.
# Validation loss decreased (541.402333 --> 524.145370).  Saving model ...
# -------------
# Epoch 10/300
# -------------
# （train）
# 365/366
# epoch 10 || Epoch_TRAIN_Loss:1.3787 ||Epoch_VAL_Loss:1.3898
# timer:  209.3830 sec.
# Validation loss decreased (524.145370 --> 510.041449).  Saving model ...
# -------------
# Epoch 11/300
# -------------
# （train）
# 365/366
# epoch 11 || Epoch_TRAIN_Loss:1.3053 ||Epoch_VAL_Loss:1.4655
# timer:  209.4648 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 12/300
# -------------
# （train）
# 365/366
# epoch 12 || Epoch_TRAIN_Loss:1.2247 ||Epoch_VAL_Loss:1.4190
# timer:  209.3730 sec.
# EarlyStopping counter: 2 out of 20
# -------------
# Epoch 13/300
# -------------
# （train）
# 365/366
# epoch 13 || Epoch_TRAIN_Loss:1.1527 ||Epoch_VAL_Loss:1.2716
# timer:  209.0427 sec.
# Validation loss decreased (510.041449 --> 466.669959).  Saving model ...
# -------------
# Epoch 14/300
# -------------
# （train）
# 365/366
# epoch 14 || Epoch_TRAIN_Loss:1.1198 ||Epoch_VAL_Loss:1.2186
# timer:  209.4307 sec.
# Validation loss decreased (466.669959 --> 447.229692).  Saving model ...
# -------------
# Epoch 15/300
# -------------
# （train）
# 365/366
# epoch 15 || Epoch_TRAIN_Loss:1.0476 ||Epoch_VAL_Loss:1.1410
# timer:  209.7629 sec.
# Validation loss decreased (447.229692 --> 418.761857).  Saving model ...
# -------------
# Epoch 16/300
# -------------
# （train）
# 365/366
# epoch 16 || Epoch_TRAIN_Loss:0.9854 ||Epoch_VAL_Loss:1.1387
# timer:  209.2157 sec.
# Validation loss decreased (418.761857 --> 417.920330).  Saving model ...
# -------------
# Epoch 17/300
# -------------
# （train）
# 365/366
# epoch 17 || Epoch_TRAIN_Loss:0.9391 ||Epoch_VAL_Loss:1.0810
# timer:  209.2702 sec.
# Validation loss decreased (417.920330 --> 396.725927).  Saving model ...
# -------------
# Epoch 18/300
# -------------
# （train）
# 365/366
# epoch 18 || Epoch_TRAIN_Loss:0.8881 ||Epoch_VAL_Loss:1.0950
# timer:  209.4212 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 19/300
# -------------
# （train）
# 365/366
# epoch 19 || Epoch_TRAIN_Loss:0.8367 ||Epoch_VAL_Loss:1.0353
# timer:  209.5178 sec.
# Validation loss decreased (396.725927 --> 379.955393).  Saving model ...
# -------------
# Epoch 20/300
# -------------
# （train）
# 365/366
# epoch 20 || Epoch_TRAIN_Loss:0.8001 ||Epoch_VAL_Loss:1.0273
# timer:  209.5267 sec.
# Validation loss decreased (379.955393 --> 377.031929).  Saving model ...
# -------------
# Epoch 21/300
# -------------
# （train）
# 365/366
# epoch 21 || Epoch_TRAIN_Loss:0.7416 ||Epoch_VAL_Loss:0.9558
# timer:  209.2668 sec.
# Validation loss decreased (377.031929 --> 350.765578).  Saving model ...
# -------------
# Epoch 22/300
# -------------
# （train）
# 365/366
# epoch 22 || Epoch_TRAIN_Loss:0.7162 ||Epoch_VAL_Loss:0.9948
# timer:  209.6245 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 23/300
# -------------
# （train）
# 365/366
# epoch 23 || Epoch_TRAIN_Loss:0.6969 ||Epoch_VAL_Loss:1.3501
# timer:  209.5527 sec.
# EarlyStopping counter: 2 out of 20
# -------------
# Epoch 24/300
# -------------
# （train）
# 365/366
# epoch 24 || Epoch_TRAIN_Loss:0.6971 ||Epoch_VAL_Loss:0.9799
# timer:  209.1284 sec.
# EarlyStopping counter: 3 out of 20
# -------------
# Epoch 25/300
# -------------
# （train）
# 365/366
# epoch 25 || Epoch_TRAIN_Loss:0.6190 ||Epoch_VAL_Loss:0.9394
# timer:  209.0803 sec.
# Validation loss decreased (350.765578 --> 344.754334).  Saving model ...
# -------------
# Epoch 26/300
# -------------
# （train）
# 365/366
# epoch 26 || Epoch_TRAIN_Loss:0.5721 ||Epoch_VAL_Loss:0.8854
# timer:  209.2130 sec.
# Validation loss decreased (344.754334 --> 324.924139).  Saving model ...
# -------------
# Epoch 27/300
# -------------
# （train）
# 365/366
# epoch 27 || Epoch_TRAIN_Loss:0.5580 ||Epoch_VAL_Loss:0.9649
# timer:  209.4309 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 28/300
# -------------
# （train）
# 365/366
# epoch 28 || Epoch_TRAIN_Loss:0.5341 ||Epoch_VAL_Loss:0.8659
# timer:  209.3256 sec.
# Validation loss decreased (324.924139 --> 317.789799).  Saving model ...
# -------------
# Epoch 29/300
# -------------
# （train）
# 365/366
# epoch 29 || Epoch_TRAIN_Loss:0.4963 ||Epoch_VAL_Loss:0.8913
# timer:  209.6466 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 30/300
# -------------
# （train）
# 365/366
# epoch 30 || Epoch_TRAIN_Loss:0.4729 ||Epoch_VAL_Loss:0.9064
# timer:  209.7506 sec.
# EarlyStopping counter: 2 out of 20
# -------------
# Epoch 31/300
# -------------
# （train）
# 365/366
# epoch 31 || Epoch_TRAIN_Loss:0.4426 ||Epoch_VAL_Loss:0.8605
# timer:  209.7149 sec.
# Validation loss decreased (317.789799 --> 315.806684).  Saving model ...
# -------------
# Epoch 32/300
# -------------
# （train）
# 365/366
# epoch 32 || Epoch_TRAIN_Loss:0.4290 ||Epoch_VAL_Loss:0.8511
# timer:  209.3007 sec.
# Validation loss decreased (315.806684 --> 312.336551).  Saving model ...
# -------------
# Epoch 33/300
# -------------
# （train）
# 365/366
# epoch 33 || Epoch_TRAIN_Loss:0.4153 ||Epoch_VAL_Loss:0.8530
# timer:  209.0979 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 34/300
# -------------
# （train）
# 365/366
# epoch 34 || Epoch_TRAIN_Loss:0.4038 ||Epoch_VAL_Loss:0.8736
# timer:  209.5164 sec.
# EarlyStopping counter: 2 out of 20
# -------------
# Epoch 35/300
# -------------
# （train）
# 365/366
# epoch 35 || Epoch_TRAIN_Loss:0.3740 ||Epoch_VAL_Loss:0.8473
# timer:  209.6275 sec.
# Validation loss decreased (312.336551 --> 310.958098).  Saving model ...
# -------------
# Epoch 36/300
# -------------
# （train）
# 365/366
# epoch 36 || Epoch_TRAIN_Loss:0.3493 ||Epoch_VAL_Loss:0.8575
# timer:  209.4378 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 37/300
# -------------
# （train）
# 365/366
# epoch 37 || Epoch_TRAIN_Loss:0.3359 ||Epoch_VAL_Loss:0.8422
# timer:  209.1605 sec.
# Validation loss decreased (310.958098 --> 309.071519).  Saving model ...
# -------------
# Epoch 38/300
# -------------
# （train）
# 365/366
# epoch 38 || Epoch_TRAIN_Loss:0.3350 ||Epoch_VAL_Loss:0.8735
# timer:  209.4796 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 39/300
# -------------
# （train）
# 365/366
# epoch 39 || Epoch_TRAIN_Loss:0.3398 ||Epoch_VAL_Loss:0.8579
# timer:  209.6918 sec.
# EarlyStopping counter: 2 out of 20
# -------------
# Epoch 40/300
# -------------
# （train）
# 365/366
# epoch 40 || Epoch_TRAIN_Loss:0.2938 ||Epoch_VAL_Loss:0.8417
# timer:  209.6007 sec.
# Validation loss decreased (309.071519 --> 308.888940).  Saving model ...
# -------------
# Epoch 41/300
# -------------
# （train）
# 365/366
# epoch 41 || Epoch_TRAIN_Loss:0.2896 ||Epoch_VAL_Loss:0.8664
# timer:  209.5372 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 42/300
# -------------
# （train）
# 365/366
# epoch 42 || Epoch_TRAIN_Loss:0.2732 ||Epoch_VAL_Loss:0.8710
# timer:  209.4127 sec.
# EarlyStopping counter: 2 out of 20
# -------------
# Epoch 43/300
# -------------
# （train）
# 365/366
# epoch 43 || Epoch_TRAIN_Loss:0.2626 ||Epoch_VAL_Loss:0.8730
# timer:  209.4771 sec.
# EarlyStopping counter: 3 out of 20
# -------------
# Epoch 44/300
# -------------
# （train）
# 365/366
# epoch 44 || Epoch_TRAIN_Loss:0.2511 ||Epoch_VAL_Loss:0.8754
# timer:  209.2440 sec.
# EarlyStopping counter: 4 out of 20
# -------------
# Epoch 45/300
# -------------
# （train）
# 365/366
# epoch 45 || Epoch_TRAIN_Loss:0.3014 ||Epoch_VAL_Loss:0.9283
# timer:  209.0641 sec.
# EarlyStopping counter: 5 out of 20
# -------------
# Epoch 46/300
# -------------
# （train）
# 365/366
# epoch 46 || Epoch_TRAIN_Loss:0.3077 ||Epoch_VAL_Loss:0.8913
# timer:  209.1046 sec.
# EarlyStopping counter: 6 out of 20
# -------------
# Epoch 47/300
# -------------
# （train）
# 365/366
# epoch 47 || Epoch_TRAIN_Loss:0.2390 ||Epoch_VAL_Loss:0.8840
# timer:  209.2018 sec.
# EarlyStopping counter: 7 out of 20
# -------------
# Epoch 48/300
# -------------
# （train）
# 365/366
# epoch 48 || Epoch_TRAIN_Loss:0.2217 ||Epoch_VAL_Loss:0.8821
# timer:  209.1897 sec.
# EarlyStopping counter: 8 out of 20
# -------------
# Epoch 49/300
# -------------
# （train）
# 365/366
# epoch 49 || Epoch_TRAIN_Loss:0.2201 ||Epoch_VAL_Loss:0.8507
# timer:  209.1798 sec.
# EarlyStopping counter: 9 out of 20
# -------------
# Epoch 50/300
# -------------
# （train）
# 365/366
# epoch 50 || Epoch_TRAIN_Loss:0.2082 ||Epoch_VAL_Loss:0.9213
# timer:  209.2303 sec.
# EarlyStopping counter: 10 out of 20
# -------------
# Epoch 51/300
# -------------
# （train）
# 365/366
# epoch 51 || Epoch_TRAIN_Loss:0.2062 ||Epoch_VAL_Loss:0.9077
# timer:  209.6438 sec.
# EarlyStopping counter: 11 out of 20
# -------------
# Epoch 52/300
# -------------
# （train）
# 365/366
# epoch 52 || Epoch_TRAIN_Loss:0.1912 ||Epoch_VAL_Loss:0.9643
# timer:  209.8362 sec.
# EarlyStopping counter: 12 out of 20
# -------------
# Epoch 53/300
# -------------
# （train）
# 365/366
# epoch 53 || Epoch_TRAIN_Loss:0.1872 ||Epoch_VAL_Loss:0.9314
# timer:  209.4726 sec.
# EarlyStopping counter: 13 out of 20
# -------------
# Epoch 54/300
# -------------
# （train）
# 365/366
# epoch 54 || Epoch_TRAIN_Loss:0.1934 ||Epoch_VAL_Loss:0.9258
# timer:  209.4583 sec.
# EarlyStopping counter: 14 out of 20
# -------------
# Epoch 55/300
# -------------
# （train）
# 365/366
# epoch 55 || Epoch_TRAIN_Loss:0.1851 ||Epoch_VAL_Loss:0.9533
# timer:  209.4682 sec.
# EarlyStopping counter: 15 out of 20
# -------------
# Epoch 56/300
# -------------
# （train）
# 365/366
# epoch 56 || Epoch_TRAIN_Loss:0.1896 ||Epoch_VAL_Loss:0.9719
# timer:  209.3354 sec.
# EarlyStopping counter: 16 out of 20
# -------------
# Epoch 57/300
# -------------
# （train）
# 365/366
# epoch 57 || Epoch_TRAIN_Loss:0.1668 ||Epoch_VAL_Loss:0.9906
# timer:  209.0328 sec.
# EarlyStopping counter: 17 out of 20
# -------------
# Epoch 58/300
# -------------
# （train）
# 365/366
# epoch 58 || Epoch_TRAIN_Loss:0.1611 ||Epoch_VAL_Loss:0.9570
# timer:  209.0600 sec.
# EarlyStopping counter: 18 out of 20
# -------------
# Epoch 59/300
# -------------
# （train）
# 365/366
# epoch 59 || Epoch_TRAIN_Loss:0.1573 ||Epoch_VAL_Loss:0.9768
# timer:  209.1020 sec.
# EarlyStopping counter: 19 out of 20
# -------------
# Epoch 60/300
# -------------
# （train）
# 365/366
# epoch 60 || Epoch_TRAIN_Loss:0.1516 ||Epoch_VAL_Loss:0.9452
# timer:  209.2043 sec.
# EarlyStopping counter: 20 out of 20
# Early_Stopping

# %%
num_epoch = 300
pd_frame = pd.DataFrame(columns=['iteration', 'phase', 'loss'])
pd_loss = train_model(net,dataloaders_dict , criterion, optimizer, 
                      num_epochs=num_epoch, file_name='weights_ring_select_7_19')
# Out:
# 使用デバイス： cuda:0
# -------------
# Epoch 1/300
# -------------
# （train）
# 216/216
# epoch 1 || Epoch_TRAIN_Loss:5.7528 ||Epoch_VAL_Loss:4.6964
# timer:  126.8080 sec.
# Validation loss decreased (inf --> 1019.111875).  Saving model ...
# -------------
# Epoch 2/300
# -------------
# （train）
# 216/216
# epoch 2 || Epoch_TRAIN_Loss:5.3458 ||Epoch_VAL_Loss:4.3489
# timer:  123.1372 sec.
# Validation loss decreased (1019.111875 --> 943.708829).  Saving model ...
# -------------
# Epoch 3/300
# -------------
# （train）
# 216/216
# epoch 3 || Epoch_TRAIN_Loss:4.5952 ||Epoch_VAL_Loss:3.3714
# timer:  123.4019 sec.
# Validation loss decreased (943.708829 --> 731.601516).  Saving model ...
# -------------
# Epoch 4/300
# -------------
# （train）
# 216/216
# epoch 4 || Epoch_TRAIN_Loss:2.9750 ||Epoch_VAL_Loss:3.8516
# timer:  123.5846 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 5/300
# -------------
# （train）
# 216/216
# epoch 5 || Epoch_TRAIN_Loss:3.2476 ||Epoch_VAL_Loss:2.4431
# timer:  123.5604 sec.
# Validation loss decreased (731.601516 --> 530.154627).  Saving model ...
# -------------
# Epoch 6/300
# -------------
# （train）
# 216/216
# epoch 6 || Epoch_TRAIN_Loss:2.3743 ||Epoch_VAL_Loss:2.4077
# timer:  123.8850 sec.
# Validation loss decreased (530.154627 --> 522.468520).  Saving model ...
# -------------
# Epoch 7/300
# -------------
# （train）
# 216/216
# epoch 7 || Epoch_TRAIN_Loss:2.2669 ||Epoch_VAL_Loss:2.5765
# timer:  123.8056 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 8/300
# -------------
# （train）
# 216/216
# epoch 8 || Epoch_TRAIN_Loss:2.1509 ||Epoch_VAL_Loss:2.0909
# timer:  123.6424 sec.
# Validation loss decreased (522.468520 --> 453.734540).  Saving model ...
# -------------
# Epoch 9/300
# -------------
# （train）
# 216/216
# epoch 9 || Epoch_TRAIN_Loss:2.0031 ||Epoch_VAL_Loss:1.9904
# timer:  123.5374 sec.
# Validation loss decreased (453.734540 --> 431.913460).  Saving model ...
# -------------
# Epoch 10/300
# -------------
# （train）
# 216/216
# epoch 10 || Epoch_TRAIN_Loss:1.9176 ||Epoch_VAL_Loss:1.9983
# timer:  123.6345 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 11/300
# -------------
# （train）
# 216/216
# epoch 11 || Epoch_TRAIN_Loss:1.8594 ||Epoch_VAL_Loss:1.9566
# timer:  123.6301 sec.
# Validation loss decreased (431.913460 --> 424.576541).  Saving model ...
# -------------
# Epoch 12/300
# -------------
# （train）
# 216/216
# epoch 12 || Epoch_TRAIN_Loss:1.7770 ||Epoch_VAL_Loss:1.8724
# timer:  123.8218 sec.
# Validation loss decreased (424.576541 --> 406.309214).  Saving model ...
# -------------
# Epoch 13/300
# -------------
# （train）
# 216/216
# epoch 13 || Epoch_TRAIN_Loss:1.7091 ||Epoch_VAL_Loss:1.7794
# timer:  123.8040 sec.
# Validation loss decreased (406.309214 --> 386.129835).  Saving model ...
# -------------
# Epoch 14/300
# -------------
# （train）
# 216/216
# epoch 14 || Epoch_TRAIN_Loss:1.6315 ||Epoch_VAL_Loss:1.7518
# timer:  123.5921 sec.
# Validation loss decreased (386.129835 --> 380.151431).  Saving model ...
# -------------
# Epoch 15/300
# -------------
# （train）
# 216/216
# epoch 15 || Epoch_TRAIN_Loss:1.5877 ||Epoch_VAL_Loss:1.6720
# timer:  123.5887 sec.
# Validation loss decreased (380.151431 --> 362.814548).  Saving model ...
# -------------
# Epoch 16/300
# -------------
# （train）
# 216/216
# epoch 16 || Epoch_TRAIN_Loss:1.5175 ||Epoch_VAL_Loss:1.6112
# timer:  123.6157 sec.
# Validation loss decreased (362.814548 --> 349.620240).  Saving model ...
# -------------
# Epoch 17/300
# -------------
# （train）
# 216/216
# epoch 17 || Epoch_TRAIN_Loss:1.4824 ||Epoch_VAL_Loss:1.6559
# timer:  123.5049 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 18/300
# -------------
# （train）
# 216/216
# epoch 18 || Epoch_TRAIN_Loss:1.4108 ||Epoch_VAL_Loss:1.6175
# timer:  123.5262 sec.
# EarlyStopping counter: 2 out of 20
# -------------
# Epoch 19/300
# -------------
# （train）
# 216/216
# epoch 19 || Epoch_TRAIN_Loss:1.3770 ||Epoch_VAL_Loss:1.6113
# timer:  123.6707 sec.
# EarlyStopping counter: 3 out of 20
# -------------
# Epoch 20/300
# -------------
# （train）
# 216/216
# epoch 20 || Epoch_TRAIN_Loss:1.3279 ||Epoch_VAL_Loss:1.5395
# timer:  123.7923 sec.
# Validation loss decreased (349.620240 --> 334.068191).  Saving model ...
# -------------
# Epoch 21/300
# -------------
# （train）
# 216/216
# epoch 21 || Epoch_TRAIN_Loss:1.3196 ||Epoch_VAL_Loss:1.6079
# timer:  123.8017 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 22/300
# -------------
# （train）
# 216/216
# epoch 22 || Epoch_TRAIN_Loss:1.2460 ||Epoch_VAL_Loss:1.5234
# timer:  123.8582 sec.
# Validation loss decreased (334.068191 --> 330.576538).  Saving model ...
# -------------
# Epoch 23/300
# -------------
# （train）
# 216/216
# epoch 23 || Epoch_TRAIN_Loss:1.1959 ||Epoch_VAL_Loss:1.6017
# timer:  123.8022 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 24/300
# -------------
# （train）
# 216/216
# epoch 24 || Epoch_TRAIN_Loss:1.1386 ||Epoch_VAL_Loss:1.5588
# timer:  123.8820 sec.
# EarlyStopping counter: 2 out of 20
# -------------
# Epoch 25/300
# -------------
# （train）
# 216/216
# epoch 25 || Epoch_TRAIN_Loss:1.1278 ||Epoch_VAL_Loss:1.4725
# timer:  123.8781 sec.
# Validation loss decreased (330.576538 --> 319.534479).  Saving model ...
# -------------
# Epoch 26/300
# -------------
# （train）
# 216/216
# epoch 26 || Epoch_TRAIN_Loss:1.0689 ||Epoch_VAL_Loss:1.4728
# timer:  123.7938 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 27/300
# -------------
# （train）
# 216/216
# epoch 27 || Epoch_TRAIN_Loss:1.0381 ||Epoch_VAL_Loss:1.4323
# timer:  123.7412 sec.
# Validation loss decreased (319.534479 --> 310.810429).  Saving model ...
# -------------
# Epoch 28/300
# -------------
# （train）
# 216/216
# epoch 28 || Epoch_TRAIN_Loss:1.0006 ||Epoch_VAL_Loss:1.3975
# timer:  123.7068 sec.
# Validation loss decreased (310.810429 --> 303.255462).  Saving model ...
# -------------
# Epoch 29/300
# -------------
# （train）
# 216/216
# epoch 29 || Epoch_TRAIN_Loss:0.9402 ||Epoch_VAL_Loss:1.3877
# timer:  123.9902 sec.
# Validation loss decreased (303.255462 --> 301.135895).  Saving model ...
# -------------
# Epoch 30/300
# -------------
# （train）
# 216/216
# epoch 30 || Epoch_TRAIN_Loss:0.9090 ||Epoch_VAL_Loss:1.3994
# timer:  123.9539 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 31/300
# -------------
# （train）
# 216/216
# epoch 31 || Epoch_TRAIN_Loss:0.8581 ||Epoch_VAL_Loss:1.4140
# timer:  123.7720 sec.
# EarlyStopping counter: 2 out of 20
# -------------
# Epoch 32/300
# -------------
# （train）
# 216/216
# epoch 32 || Epoch_TRAIN_Loss:0.8529 ||Epoch_VAL_Loss:1.4112
# timer:  123.7698 sec.
# EarlyStopping counter: 3 out of 20
# -------------
# Epoch 33/300
# -------------
# （train）
# 216/216
# epoch 33 || Epoch_TRAIN_Loss:0.8121 ||Epoch_VAL_Loss:1.4442
# timer:  123.7659 sec.
# EarlyStopping counter: 4 out of 20
# -------------
# Epoch 34/300
# -------------
# （train）
# 216/216
# epoch 34 || Epoch_TRAIN_Loss:0.7788 ||Epoch_VAL_Loss:1.3619
# timer:  123.7258 sec.
# Validation loss decreased (301.135895 --> 295.538722).  Saving model ...
# -------------
# Epoch 35/300
# -------------
# （train）
# 216/216
# epoch 35 || Epoch_TRAIN_Loss:0.7302 ||Epoch_VAL_Loss:1.3584
# timer:  123.6730 sec.
# Validation loss decreased (295.538722 --> 294.767535).  Saving model ...
# -------------
# Epoch 36/300
# -------------
# （train）
# 216/216
# epoch 36 || Epoch_TRAIN_Loss:0.7060 ||Epoch_VAL_Loss:1.4941
# timer:  123.6659 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 37/300
# -------------
# （train）
# 216/216
# epoch 37 || Epoch_TRAIN_Loss:0.6578 ||Epoch_VAL_Loss:1.3166
# timer:  123.7297 sec.
# Validation loss decreased (294.767535 --> 285.708888).  Saving model ...
# -------------
# Epoch 38/300
# -------------
# （train）
# 216/216
# epoch 38 || Epoch_TRAIN_Loss:0.6137 ||Epoch_VAL_Loss:1.3308
# timer:  123.7791 sec.
# EarlyStopping counter: 1 out of 20
# -------------
# Epoch 39/300
# -------------
# （train）
# 216/216
# epoch 39 || Epoch_TRAIN_Loss:0.6023 ||Epoch_VAL_Loss:1.4398
# timer:  123.8335 sec.
# EarlyStopping counter: 2 out of 20
# -------------
# Epoch 40/300
# -------------
# （train）
# 216/216
# epoch 40 || Epoch_TRAIN_Loss:0.5747 ||Epoch_VAL_Loss:1.3283
# timer:  123.7339 sec.
# EarlyStopping counter: 3 out of 20
# -------------
# Epoch 41/300
# -------------
# （train）
# 216/216
# epoch 41 || Epoch_TRAIN_Loss:0.5420 ||Epoch_VAL_Loss:1.3590
# timer:  123.6245 sec.
# EarlyStopping counter: 4 out of 20
# -------------
# Epoch 42/300
# -------------
# （train）
# 216/216
# epoch 42 || Epoch_TRAIN_Loss:0.5321 ||Epoch_VAL_Loss:1.3594
# timer:  123.8039 sec.
# EarlyStopping counter: 5 out of 20
# -------------
# Epoch 43/300
# -------------
# （train）
# 216/216
# epoch 43 || Epoch_TRAIN_Loss:0.5230 ||Epoch_VAL_Loss:1.3724
# timer:  123.8199 sec.
# EarlyStopping counter: 6 out of 20
# -------------
# Epoch 44/300
# -------------
# （train）
# 216/216
# epoch 44 || Epoch_TRAIN_Loss:0.4750 ||Epoch_VAL_Loss:1.4797
# timer:  123.7345 sec.
# EarlyStopping counter: 7 out of 20
# -------------
# Epoch 45/300
# -------------
# （train）
# 216/216
# epoch 45 || Epoch_TRAIN_Loss:0.4570 ||Epoch_VAL_Loss:1.4100
# timer:  123.9732 sec.
# EarlyStopping counter: 8 out of 20
# -------------
# Epoch 46/300
# -------------
# （train）
# 216/216
# epoch 46 || Epoch_TRAIN_Loss:0.4400 ||Epoch_VAL_Loss:1.4727
# timer:  123.9628 sec.
# EarlyStopping counter: 9 out of 20
# -------------
# Epoch 47/300
# -------------
# （train）
# 216/216
# epoch 47 || Epoch_TRAIN_Loss:0.4345 ||Epoch_VAL_Loss:1.4365
# timer:  123.9026 sec.
# EarlyStopping counter: 10 out of 20
# -------------
# Epoch 48/300
# -------------
# （train）
# 216/216
# epoch 48 || Epoch_TRAIN_Loss:0.4041 ||Epoch_VAL_Loss:1.3730
# timer:  123.7613 sec.
# EarlyStopping counter: 11 out of 20
# -------------
# Epoch 49/300
# -------------
# （train）
# 216/216
# epoch 49 || Epoch_TRAIN_Loss:0.3701 ||Epoch_VAL_Loss:1.4408
# timer:  123.5685 sec.
# EarlyStopping counter: 12 out of 20
# -------------
# Epoch 50/300
# -------------
# （train）
# 216/216
# epoch 50 || Epoch_TRAIN_Loss:0.3520 ||Epoch_VAL_Loss:1.4005
# timer:  124.1355 sec.
# EarlyStopping counter: 13 out of 20
# -------------
# Epoch 51/300
# -------------
# （train）
# 216/216
# epoch 51 || Epoch_TRAIN_Loss:0.3466 ||Epoch_VAL_Loss:1.4353
# timer:  123.9269 sec.
# EarlyStopping counter: 14 out of 20
# -------------
# Epoch 52/300
# -------------
# （train）
# 216/216
# epoch 52 || Epoch_TRAIN_Loss:0.3386 ||Epoch_VAL_Loss:1.4598
# timer:  123.9946 sec.
# EarlyStopping counter: 15 out of 20
# -------------
# Epoch 53/300
# -------------
# （train）
# 216/216
# epoch 53 || Epoch_TRAIN_Loss:0.3185 ||Epoch_VAL_Loss:1.4634
# timer:  124.0693 sec.
# EarlyStopping counter: 16 out of 20
# -------------
# Epoch 54/300
# -------------
# （train）
# 216/216
# epoch 54 || Epoch_TRAIN_Loss:0.3276 ||Epoch_VAL_Loss:1.4487
# timer:  123.9085 sec.
# EarlyStopping counter: 17 out of 20
# -------------
# Epoch 55/300
# -------------
# （train）
# 216/216
# epoch 55 || Epoch_TRAIN_Loss:0.3100 ||Epoch_VAL_Loss:1.4642
# timer:  123.8834 sec.
# EarlyStopping counter: 18 out of 20
# -------------
# Epoch 56/300
# -------------
# （train）
# 216/216
# epoch 56 || Epoch_TRAIN_Loss:0.3014 ||Epoch_VAL_Loss:1.6187
# timer:  123.7699 sec.
# EarlyStopping counter: 19 out of 20
# -------------
# Epoch 57/300
# -------------
# （train）
# 216/216
# epoch 57 || Epoch_TRAIN_Loss:0.2878 ||Epoch_VAL_Loss:1.4611
# timer:  123.6631 sec.
# EarlyStopping counter: 20 out of 20
# Early_Stopping
